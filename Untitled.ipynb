# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('NASC_Household_Table3.csv')

# %%
data.describe()
# Out:
#            Unnamed: 0  \
# count              45
# unique              8
# top     North Central
# freq                8
#
#        Table 3 Distribution of Head of agricultural HH by sex and age  \
# count                                                  46
# unique                                                 41
# top                                            Zone total
# freq                                                    6
#
#        Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# count          46         45         45         45         45         45
# unique         30         39         34         35         35         38
# top           2.8       22.9       24.8       25.9       11.8        9.1
# freq            3          2          3          4          4          3
#
#        Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# count          46         45          45          45          45          45
# ...

# %%
data.head()
# Out:
#       Unnamed: 0  \
# 0            NaN
# 1           Zone
# 2  North Central
# 3  North Central
# 4  North Central
#
#   Table 3 Distribution of Head of agricultural HH by sex and age  \
# 0                                                NaN
# 1                                              State
# 2                                              Benue
# 3                                                Fct
# 4                                               Kogi
#
#                                           Unnamed: 2   Unnamed: 3  \
# 0  Distribution of Head of agricultural Household...          NaN
# 1                                       15-24 years   25-34 years
# 2                                                4.8         21.9
# 3                                                2.3         19.7
# 4                                                2.8         16.7
#
#     Unnamed: 4   Unnamed: 5   Unnamed: 6          Unnamed: 7  \
# ...
