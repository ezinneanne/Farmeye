# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.array([[0.05,0.93,0.02,0.0],[0.10,0.86,0.04,0.0],[0.0,0.0,0.80,0.20],[0.50,0.10,0.0,0.4]])

# %%
# Number of hours to simulate
time_steps = 24

# Initialize list to store the expected number of machines in each state at each hour
expected_machines = [initial_state]  # Initial state with all machines Working

# Loop over each hour to calculate expected machine distribution
for t in range(1, time_steps + 1):
    next_state = expected_machines[-1] @ A  # Compute next state distribution
    expected_machines.append(next_state)     # Store the result

# Convert list to numpy array for easier manipulation and display
expected_machines = np.array(expected_machines)
expected_machines
# Out:
# array([[  0.        , 200.        ,   0.        ,   0.        ],
#        [ 20.        , 172.        ,   8.        ,   0.        ],
#        [ 18.2       , 166.52      ,  13.68      ,   1.6       ],
#        [ 18.362     , 160.2932    ,  17.9688    ,   3.376     ],
#        [ 18.63542   , 155.266412  ,  21.154008  ,   4.94416   ],
#        [ 18.9304922 , 151.35447092,  23.50657128,   6.2084656 ],
#        [ 19.1862045 , 148.3910493 ,  25.2380457 ,   7.1847005 ],
#        [ 19.3907654 , 146.17794263,  26.50980263,   7.92148934],
#        [ 19.5480772 , 144.53859142,  27.44277511,   8.47055626],
#        [ 19.66654113, 143.32995605,  28.12672529,   8.87677753],
#        [ 19.75471143, 142.44132321,  28.6279093 ,   9.17605607],
#        [ 19.81989593, 141.78902519,  28.9950746 ,   9.39600429],
#        [ 19.86789946, 141.3106653 ,  29.2640186 ,   9.55741663],
#        [ 19.90316982, 140.96006032,  29.46099948,   9.67577037],
# ...

# %%
initial_state = np.array([0, 200, 0, 0])  # [Idle, Working, Broken, Repair]

# %%
# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(expected_machines[:, 0], label="Idle")
plt.plot(expected_machines[:, 1], label="Working")
plt.plot(expected_machines[:, 2], label="Broken")
plt.plot(expected_machines[:, 3], label="Repair")

# Add titles and labels
plt.title("Machine State Distribution Over Time")
plt.xlabel("Time (hours)")
plt.ylabel("Number of Machines")
plt.legend(loc="upper right")
plt.grid()
plt.show()

# %%
# Calculate the eigenvalues and eigenvectors of A
eigenvalues, eigenvectors = np.linalg.eig(A)

# Display eigenvalues and eigenvectors
print("Eigenvalues:", eigenvalues)
print("Eigenvectors:\n", eigenvectors)
# Out:
# Eigenvalues: [-0.05659878  0.43426882  1.          0.73232996]
# Eigenvectors:
#  [[ 0.67131544 -0.05353229  0.5        -0.17723716]
#  [-0.08055032 -0.03241708  0.5        -0.14985146]
#  [ 0.16751946  0.47885478  0.5         0.92138143]
#  [-0.71748481 -0.87566062  0.5        -0.31174958]]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Initial state: all machines are Working
initial_state = np.array([0, 200, 0, 0, 0])

# Track time steps and states
time_steps = 0
current_state = initial_state

# Loop until Working machines drop below 20
while current_state[1] >= 20:
    current_state = current_state @ A  # Update state distribution
    time_steps += 1

# Results
time_steps, current_state# for answer 3a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 13
#      11 # Loop until Working machines drop below 20
#      12 while current_state[1] >= 20:
# ---> 13     current_state = current_state @ A  # Update state distribution
#      14     time_steps += 1
#      16 # Results
#
# NameError: name 'A' is not defined

# %%
import sklearn.datasets

# %%
from sklearn.datasets import fetch_olivetti_faces

# %%
olivetti_faces = fetch_olivetti_faces()
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to C:\Users\LENOVO\scikit_learn_data

# %%
olivetti_faces.data.shape
(400, 4096)
# Out:
# (400, 4096)

# %%
olivetti_faces.target.shape
# Out:
# (400,)

# %%
olivetti_faces.images.shape
# Out:
# (400, 64, 64)

# %%
faces = olivetti_faces

# %%
Xall = faces.data.T

# %%
print(Xall.shape)
# Out:
# (4096, 400)

# %%
print(Xall.min(), Xall.max())
# Out:
# 0.0 1.0

# %%
Xsub = Xall[:,0:200]
print(Xsub.shape)
# Out:
# (4096, 200)

# %%
xbar = np.mean(Xsub, axis=1)

# %%
xbar = xbar.reshape(4096, 1)

# %%
print(xbar.shape)
# Out:
# (4096, 1)

# %%
mean_face = xbar.reshape(64, 64)

# %%
ID_last_two_digits = 45

# %%
student_face = Xsub[:, ID_last_two_digits].reshape(64, 64)

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(mean_face, cmap=plt.cm.gray, vmin=0, vmax=1)
plt.title("Mean Face")
plt.axis('off')

# Plot the specific face image
plt.subplot(1, 2, 2)
plt.imshow(student_face, cmap=plt.cm.gray, vmin=0, vmax=1)
plt.title(f"Face {ID_last_two_digits}")
plt.axis('off')

plt.show()

# %%
# Step 1: Calculate the covariance matrix of Xsub
C = np.cov(Xsub)  # 4096 × 4096 covariance matrix
# Task 2 no 2
