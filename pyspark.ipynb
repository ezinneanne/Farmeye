# %%
# !pip install pyspark
# Out:
# ...
#      ---------------------------------------- 0.0/317.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.2 MB ? eta -:--:--
# ...

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.master("local[*]").getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 spark = SparkSession.builder.master("local[*]").getOrCreate()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyspark\sql\session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# --> 497 sc = SparkContext.getOrCreate(sparkConf)
#     498 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499 # by all sessions.
#     500 session = SparkSession(sc, options=self._options)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyspark\context.py:515, in SparkContext.getOrCreate(cls, conf)
#     513 with SparkContext._lock:
#     514     if SparkContext._active_spark_context is None:
# --> 515         SparkContext(conf=conf or SparkConf())
# ...

# %%
java -version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 java -version
#
# NameError: name 'java' is not defined
